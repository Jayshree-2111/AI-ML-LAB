# %% [markdown]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: #https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("Hello")

# %%
a=3
b=3.0
c='3'
print(type(a))
print(type(b))
print(type(c))

#to print the data type of the variables

# %%
a=input("Enter a number: ")
a

# %%
a=input("Enter a number: ")
a=a*2
a

# %%
a=input("Enter a number: ")
#a=a+2 this will give error
a=int(a)+2
a

# %%
a=input("Enter a number: ")
#a=a+2 this will give error
a=int(a)+2.0 #type casting
a

# %%
a=input("Enter a number: ")
a=int(a)/2  #it will show full answer
a

# %%
a=input("Enter a number: ")
a=int(a)//2  #it will show only integer part
a

# %%
a=input("Enter a number: ")
a=int(a)**2
a

# %%
a=input("Enter a number: ")
a=int(a)%2 #modulo operator gives remainder
a

# %%
a=input("Enter a number: ") 
#for commenting multiple lines
"""a=int(a)%2
   a"""

# %%
x=7
if x<9: #indentation is important and by writing colon we will get 4 spaces
#print(x) will give indentation error
    print(x)

# %%
x=7
if x<9:
    print(x)
    print("hi")

# %%
x=10
if x<9:
    print(x)
print("hi") #not in the block of if

# %%
x="Banasthali Vidyapith"
print(x[0]) #to access characters by their indexes, indexing start from 0
print(x[5])

# %%
x="Banasthali Vidyapith"
print(len(x)) #to get length of the string

# %%
for i in range(1,20,1):
    print(i)

# %%
for i in range(1,20,2):
    print(i)

# %%
for i in range(20,1,-2):
    print(i)

# %%
i=1
while i<20:
    print(i)
    i=i+1

# %%
i=20
while i>0:
    print(i)
    i=i-1

# %%
x=10
if x<9:
    print(x)
else:
    print("hi")

# %%
x=10
if x<9:
    print(x)
elif x>9:
    print("hi")
